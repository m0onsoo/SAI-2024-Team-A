# %%
cd /content/drive/MyDrive/Colab Notebooks/SAI/RF-HPO
# Out:
# /content/drive/MyDrive/Colab Notebooks/SAI/RF-HPO

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# References
# https://github.com/bayesian-optimization/BayesianOptimization
# https://drlee.io/step-by-step-guide-bayesian-optimization-with-random-forest-fdc6f329db9c

# %%
pip install bayesian-optimization

# %% [markdown]
# #### 추가해야할 작업

# %% [markdown]
# requirements.txt 작성해 필요한 모듈 버전 관리

# %%
import sys
import pandas as pd
import sklearn

# %%
print(f"sys=={sys.version}")
print(f"pandas=={pd.__version__}")
print(f"sklearn=={sklearn.__version__}")
# Out:
# sys==3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# pandas==1.5.3
# sklearn==1.2.2

# %% [markdown]
# ### 실행 예시
# !! 현재는 iter와 랜덤한 서치 횟수를 적게해 성능이 좋지 않음

# %% [markdown]
# 실행 명령어는 다음과 같습니다.
#
# `!python RF-HPO-Park.py gini 1 sqrt  `
#
# 1번째 인자[Criterion]는 (gini, entropy, log_loss) 중에 하나,
# 2번째 인자[bootstrap]는 (0, 1) 중에 하나,
# 3번째 인자[max_features]는 (sqrt, log2, 혹은 입력하지 않으면 자동으로 None) 중에 하나
# 입니다.

# %%
# !python RF-HPO-Park.py gini 1
# Out:
# |   iter    |  target   | max_depth | max_le... | min_im... | min_sa... | min_sa... | min_we... | n_esti... |
# -------------------------------------------------------------------------------------------------------------
# | 1         | 0.5       | 10.62     | 1.949e+03 | 0.183     | 0.2993    | 2.468     | 0.078     | 67.5      |
# | 2         | 0.5       | 17.99     | 1.244e+03 | 0.177     | 0.01029   | 4.91      | 0.4162    | 220.2     |
# | 3         | 0.5       | 7.727     | 401.7     | 0.07606   | 0.2624    | 3.296     | 0.1456    | 615.7     |
# | 4         | 0.5       | 7.092     | 621.0     | 0.09159   | 0.228     | 4.356     | 0.09984   | 519.1     |
# | 5         | 0.5       | 13.89     | 125.6     | 0.1519    | 0.08526   | 2.195     | 0.4744    | 966.0     |
# | 6         | 0.5       | 17.13     | 646.1     | 0.02442   | 0.3421    | 3.32      | 0.06102   | 500.2     |
# ...

# %%
# !python RF-HPO-Park.py log_loss 0 sqrt
# Out:
# |   iter    |  target   | max_depth | max_le... | min_im... | min_sa... | min_sa... | min_we... | n_esti... |
# -------------------------------------------------------------------------------------------------------------
# | 1         | 0.5       | 10.62     | 1.949e+03 | 0.183     | 0.2993    | 2.468     | 0.078     | 67.5      |
# | 2         | 0.5       | 17.99     | 1.244e+03 | 0.177     | 0.01029   | 4.91      | 0.4162    | 220.2     |
# | 3         | 0.5       | 7.727     | 401.7     | 0.07606   | 0.2624    | 3.296     | 0.1456    | 615.7     |
# | 4         | 0.5       | 7.092     | 621.0     | 0.09159   | 0.228     | 4.356     | 0.09984   | 519.1     |
# | 5         | 0.5       | 13.89     | 125.6     | 0.1519    | 0.08526   | 2.195     | 0.4744    | 966.0     |
# | 6         | 0.5       | 13.7      | 2.009e+03 | 0.1729    | 0.0571    | 4.244     | 0.2131    | 992.4     |
# ...

# %%
# !python RF-HPO-Park.py entropy 0 log2
# Out:
# |   iter    |  target   | max_depth | max_le... | min_im... | min_sa... | min_sa... | min_we... | n_esti... |
# -------------------------------------------------------------------------------------------------------------
# | 1         | 0.5       | 10.62     | 1.949e+03 | 0.183     | 0.2993    | 2.468     | 0.078     | 67.5      |
# | 2         | 0.5       | 17.99     | 1.244e+03 | 0.177     | 0.01029   | 4.91      | 0.4162    | 220.2     |
# | 3         | 0.5       | 7.727     | 401.7     | 0.07606   | 0.2624    | 3.296     | 0.1456    | 615.7     |
# | 4         | 0.5       | 7.092     | 621.0     | 0.09159   | 0.228     | 4.356     | 0.09984   | 519.1     |
# | 5         | 0.5       | 13.89     | 125.6     | 0.1519    | 0.08526   | 2.195     | 0.4744    | 966.0     |
# | 6         | 0.5       | 13.7      | 2.009e+03 | 0.1729    | 0.0571    | 4.244     | 0.2131    | 992.4     |
# ...
